# %% [markdown]
# ### Import Module

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'  # hide warn log information 

import tensorflow as tf                   # model
import numpy as np                        # argmax
import matplotlib.pyplot as plt           # plot images

# %% [markdown]
# ### Load data and Preprocessing

# %%
# load mnist dataset
(training_images, training_labels), (test_images, test_labels) = tf.keras.datasets.mnist.load_data()

# scale or normalize the datasets
training_images=training_images/255.0
test_images=test_images/255.0

# print the shape of the dataset
training_images.shape, test_images.shape
# Out:
# ((60000, 28, 28), (10000, 28, 28))

# %% [markdown]
# ### Plot some images

# %%
fig, axs = plt.subplots(4, 4, figsize=(6,6))

k = 0
for i in range(4):
    for j in range(4):
        axs[i, j].imshow(training_images[k])
        axs[i, j].axis('off')
        axs[i, j].set_title(training_labels[k])
        k += 1

fig.tight_layout()
plt.show()

# %% [markdown]
# ### Create model

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28,28), name='input'),            # 28 * 28 => (784,1)
  tf.keras.layers.Dense(128, activation=tf.nn.relu, name='hidden_1'),
  tf.keras.layers.Dense(64, activation=tf.nn.relu, name='hidden_2'),
  tf.keras.layers.Dense(32, activation=tf.nn.relu, name='hidden_3'),
  tf.keras.layers.Dense(10, activation=tf.nn.softmax, name='output')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (Flatten)             (None, 784)               0
#
#  hidden_1 (Dense)            (None, 128)               100480
#
#  hidden_2 (Dense)            (None, 64)                8256
#
#  hidden_3 (Dense)            (None, 32)                2080
#
#  output (Dense)              (None, 10)                330
#
# =================================================================
# Total params: 111,146
# Trainable params: 111,146
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compile model

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ### Fit model

# %%
history = model.fit(training_images, training_labels, epochs=20, validation_data=(test_images, test_labels))
# Out:
# Epoch 1/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2513 - accuracy: 0.9251 - val_loss: 0.1245 - val_accuracy: 0.9623
# Epoch 2/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1042 - accuracy: 0.9687 - val_loss: 0.0990 - val_accuracy: 0.9700
# Epoch 3/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0744 - accuracy: 0.9764 - val_loss: 0.1013 - val_accuracy: 0.9665
# Epoch 4/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0581 - accuracy: 0.9817 - val_loss: 0.0848 - val_accuracy: 0.9737
# Epoch 5/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0484 - accuracy: 0.9845 - val_loss: 0.0884 - val_accuracy: 0.9732
# Epoch 6/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0386 - accuracy: 0.9876 - val_loss: 0.0804 - val_accuracy: 0.9784
# Epoch 7/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0345 - accuracy: 0.9891 - val_loss: 0.0914 - val_accuracy: 0.9770
# Epoch 8/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0302 - accuracy: 0.9903 - val_loss: 0.0837 - val_accuracy: 0.9773
# Epoch 9/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0237 - accuracy: 0.9918 - val_loss: 0.1229 - val_accuracy: 0.9704
# Epoch 10/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0223 - accuracy: 0.9927 - val_loss: 0.0925 - val_accuracy: 0.9782
# Epoch 11/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0223 - accuracy: 0.9929 - val_loss: 0.0907 - val_accuracy: 0.9778
# Epoch 12/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0181 - accuracy: 0.9939 - val_loss: 0.0978 - val_accuracy: 0.9770
# Epoch 13/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0169 - accuracy: 0.9944 - val_loss: 0.1231 - val_accuracy: 0.9731
# Epoch 14/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0165 - accuracy: 0.9947 - val_loss: 0.1008 - val_accuracy: 0.9786
# Epoch 15/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0145 - accuracy: 0.9952 - val_loss: 0.1054 - val_accuracy: 0.9781
# Epoch 16/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0140 - accuracy: 0.9954 - val_loss: 0.1076 - val_accuracy: 0.9756
# Epoch 17/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0152 - accuracy: 0.9951 - val_loss: 0.1055 - val_accuracy: 0.9798
# Epoch 18/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0141 - accuracy: 0.9954 - val_loss: 0.0951 - val_accuracy: 0.9780
# Epoch 19/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0104 - accuracy: 0.9965 - val_loss: 0.1137 - val_accuracy: 0.9777
# Epoch 20/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0108 - accuracy: 0.9966 - val_loss: 0.1102 - val_accuracy: 0.9791

# %% [markdown]
# ### Plot History - Loss and Accuracy

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 7))

# Plot the training and validation loss
ax1.plot(history.history['loss'], label='Training loss')
ax1.plot(history.history['val_loss'], label='Validation loss')
ax1.set_title('Training and Validation Loss')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.legend()

# Plot the training and validation accuracy
ax2.plot(history.history['accuracy'], label='Training accuracy')
ax2.plot(history.history['val_accuracy'], label='Validation accuracy')
ax2.set_title('Training and Validation Accuracy')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy')
ax2.legend()

plt.show()

# %% [markdown]
# ### Output

# %%
results = model.evaluate(test_images, test_labels)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1102 - accuracy: 0.9791

# %%
print("Loss       : {}".format(results[0]))
print("Accuracy   : {}".format(results[1]))
# Out:
# Loss       : 0.11016295105218887
# Accuracy   : 0.9790999889373779

# %%
classifications = model.predict(test_images[:16])

fig, axs = plt.subplots(4, 4, figsize=(8,6))

k = 0
for i in range(4):
    for j in range(4):
        axs[i, j].imshow(test_images[k], cmap='gray')
        axs[i, j].axis('off')
        if test_labels[k] == np.argmax(classifications[k]):
            axs[i, j].set_title(np.argmax(classifications[k]), fontsize=20, color='green')
        else:
            axs[i, j].set_title(np.argmax(classifications[k]), fontsize=20, color='red')
        k += 1

fig.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 88ms/step

# %% [markdown]
# ### Save model

# %%
model.save('mnist_hand_written.h5')

# %% [markdown]
# ### Create API for Production

# %% [markdown]
# #### Under testing

# %%
# Fetch the Keras session and save the model
# The signature definition is defined by the input and output tensors,
# and stored with the default serving key
import tempfile

MODEL_DIR = tempfile.gettempdir()
version = 1
export_path = os.path.join(MODEL_DIR, str(version))
print('export_path = {}\n'.format(export_path))

tf.keras.models.save_model(
    model,
    export_path,
    overwrite=True,
    include_optimizer=True,
    save_format=None,
    signatures=None,
    options=None
)

print('\nSaved model:')
# !ls -l {export_path}
# Out:
# export_path = /tmp/1
#
# INFO:tensorflow:Assets written to: /tmp/1/assets
#
# Saved model:
# total 136
# drwxr-xr-x 2 nahid nahid   4096 মার্চ      9 11:03 assets
# -rw-r--r-- 1 nahid nahid  11572 মার্চ      9 11:03 keras_metadata.pb
# -rw-r--r-- 1 nahid nahid 116616 মার্চ      9 11:03 saved_model.pb
# drwxr-xr-x 2 nahid nahid   4096 মার্চ      9 11:03 variables
